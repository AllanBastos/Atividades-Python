# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('datatranAll.csv',low_memory=False)

# %%
df
# Out:
#          Unnamed: 0   ano     br  \
# 0                 0  2007    381
# 1                 1  2007    381
# 2                 2  2007     40
# 3                 3  2007    135
# 4                 4  2007    222
# 5                 5  2007    230
# 6                 6  2007    277
# 7                 7  2007    101
# 8                 8  2007    251
# 9                 9  2007     40
# 10               10  2007     70
# 11               11  2007    116
# 12               12  2007    101
# 13               13  2007    158
# 14               14  2007    116
# 15               15  2007    116
# 16               16  2007    381
# 17               17  2007    116
# 18               18  2007    116
# 19               19  2007     40
# 20               20  2007    116
# 21               21  2007    381
# 22               22  2007     40
# 23               23  2007    101
# 24               24  2007    280
# 25               25  2007    277
# 26               26  2007     40
# ...

# %%
l = ((df[df['ano']==2010].uf).value_counts())
l.plot.bar(stacked=True)
plt.grid()
plt.show()
